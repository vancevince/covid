# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from requests.utils import requote_uri

# %%
covid_sc_url = 'https://scdhec.gov/sites/default/files/afs-covid/county-dashboard/Suppressed County Data by Week.csv'
covid_sc_url = requote_uri(covid_sc_url)
covid_sc = pd.read_csv(covid_sc_url)

# %%
covid_sc
# Out:
#             Day Week Ends On  Sort County x Week     County  \
# 0      3/21/2020 12:00:00 AM                   1  Abbeville
# 1      3/28/2020 12:00:00 AM                   2  Abbeville
# 2       4/4/2020 12:00:00 AM                   3  Abbeville
# 3      4/11/2020 12:00:00 AM                   4  Abbeville
# 4      4/18/2020 12:00:00 AM                   5  Abbeville
# ...                      ...                 ...        ...
# 4197  11/20/2021 12:00:00 AM                4198       York
# 4198  11/27/2021 12:00:00 AM                4199       York
# 4199   12/4/2021 12:00:00 AM                4200       York
# 4200  12/11/2021 12:00:00 AM                4201       York
# 4201  12/18/2021 12:00:00 AM                4202       York
#
#      Count Confirmed Cases Suppressed if 1-4  \
# 0                                         <5
# 1                                         <5
# 2                                         <5
# 3                                         <5
# 4                                          8
# ...                                      ...
# 4197                                     296
# 4198                                     236
# 4199                                     424
# 4200                                     472
# 4201                                     435
#
#      Count Probable Cases Suppressed if 1-4  \
# 0                                        <5
# 1                                        <5
# 2                                        <5
# 3                                        <5
# 4                                        <5
# ...                                     ...
# 4197                                     87
# 4198                                     73
# 4199                                    106
# 4200                                    155
# 4201                                    131
#
#      Count Hospitalized Cases Suppressed if 1-4  \
# 0                                            <5
# 1                                            <5
# 2                                            <5
# 3                                            <5
# 4                                            <5
# ...                                         ...
# 4197                                          7
# 4198                                          9
# 4199                                          8
# 4200                                         22
# 4201                                         18
#
#      Count Deceased Cases Suppressed if 1-4
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 4197                                     <5
# 4198                                    NaN
# 4199                                     <5
# 4200                                     <5
# 4201                                     <5
#
# [4202 rows x 7 columns]

# %%
# show the most recent data
covid_sc['Day Week Ends On'] = pd.to_datetime(covid_sc['Day Week Ends On'])
most_recent = covid_sc['Day Week Ends On'].max()
most_recent_data = covid_sc.loc[covid_sc['Day Week Ends On'] == most_recent]
most_recent_data
# Out:
#      Day Week Ends On  Sort County x Week        County  \
# 87         2021-12-18                  88     Abbeville
# 179        2021-12-18                 180         Aiken
# 263        2021-12-18                 264     Allendale
# 356        2021-12-18                 357      Anderson
# 445        2021-12-18                 446       Bamberg
# 534        2021-12-18                 535      Barnwell
# 627        2021-12-18                 628      Beaufort
# 719        2021-12-18                 720      Berkeley
# 808        2021-12-18                 809       Calhoun
# 902        2021-12-18                 903    Charleston
# 992        2021-12-18                 993      Cherokee
# 1084       2021-12-18                1085       Chester
# 1175       2021-12-18                1176  Chesterfield
# 2646                                     42
# 2737                                     48
# 2829                                     13
# 2922                                    164
# 3013                                     14
# 3104                                     14
# 3192                                     <5
# 3284                                     12
# 3376                                     18
# 3469                                     18
# 3561                                     22
# 3653                                    144
# 3744                                     <5
# 3837                                     92
# 3929                                     92
# 4018                                     16
# 4109                                      8
# 4201                                    131
#
#      Count Hospitalized Cases Suppressed if 1-4  \
# 87                                           <5
# 179                                           9
# 263                                          <5
# 356                                           8
# 445                                          <5
# 534                                          <5
# 627                                          <5
# 719                                           8
# 808                                          <5
# 902                                           7
# 992                                          <5
# 1084                                         <5
# 1175                                         <5
# 1267                                         <5
# 1358                                         <5
# 1450                                          5
# 1540                                         <5
# 1632                                          8
# 1724                                         <5
# 1816                                         <5
# 1908                                          5
# 2000                                         <5
# 2093                                         25
# 2185                                         <5
# 2274                                         <5
# 2367                                         11
# 2459                                         <5
# 2553                                          6
# 2646                                         <5
# 2737                                         <5
# 2829                                         <5
# 2922                                         10
# 3013                                         <5
# 3104                                         <5
# 3192                                         <5
# 3284                                         <5
# 3376                                         11
# 3469                                         <5
# 3561                                          7
# 3653                                          7
# 3744                                         <5
# 3837                                         17
# 3929                                          5
# 4018                                         <5
# 4109                                         <5
# 4201                                         18
#
#      Count Deceased Cases Suppressed if 1-4
# 87                                      NaN
# 179                                      <5
# 263                                     NaN
# 356                                       6
# 445                                     NaN
# 534                                     NaN
# 627                                      <5
# 719                                      <5
# 808                                     NaN
# 902                                      <5
# 992                                      <5
# 1084                                    NaN
# 1175                                     <5
# 1267                                    NaN
# 1358                                     <5
# 1450                                    NaN
# 1540                                    NaN
# 1632                                     <5
# 1724                                    NaN
# 1816                                    NaN
# 1908                                    NaN
# 2000                                     <5
# 2093                                      9
# 2185                                     <5
# 2274                                    NaN
# 2367                                      5
# 2459                                    NaN
# 2553                                    NaN
# 2646                                      6
# 2737                                     <5
# 2829                                     <5
# 2922                                     <5
# 3013                                    NaN
# 3104                                     <5
# 3192                                    NaN
# 3284                                    NaN
# 3376                                     <5
# 3469                                    NaN
# 3561                                      8
# 3653                                     <5
# 3744                                     <5
# 3837                                     11
# 3929                                     <5
# 4018                                     <5
# 4109                                     <5
# 4201                                     <5

# %%
# get SC county dimension data
usa_counties = geopandas.read_file('cb_2017_us_county_20m.shp')
sc_counties = usa_counties.loc[usa_counties['STATEFP'] == '45']
sc_counties.head()
# Out:
#     STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID       NAME LSAD  \
# 35       45      077  01248015  0500000US45077  45077    Pickens   06
# 103      45      059  01248009  0500000US45059  45059    Laurens   06
# 192      45      063  01244251  0500000US45063  45063  Lexington   06
# 194      45      011  01247983  0500000US45011  45011   Barnwell   06
# 198      45      023  01247988  0500000US45023  45023    Chester   06
#
#           ALAND     AWATER                                           geometry
# 35   1285538264   40609723  POLYGON ((-82.94360 34.98815, -82.89750 35.056...
# 103  1848783527   25949287  POLYGON ((-82.31400 34.48400, -82.23613 34.535...
# 192  1810553251  151957530  POLYGON ((-81.47197 34.07655, -81.39412 34.071...
# 194  1420294943   23008120  POLYGON ((-81.76251 33.19727, -81.74252 33.208...
# 198  1503893316   14261786  POLYGON ((-81.45630 34.79252, -81.47845 34.821...

# %%
merge = pd.merge(left=sc_counties[['geometry', 'NAME']],
                 right=most_recent_data,
                 left_on='NAME',
                 right_on='County',).drop(columns=['NAME'])
merge.head()
# Out:
#                                             geometry Day Week Ends On  \
# 0  POLYGON ((-82.94360 34.98815, -82.89750 35.056...       2021-12-18
# 1  POLYGON ((-82.31400 34.48400, -82.23613 34.535...       2021-12-18
# 2  POLYGON ((-81.47197 34.07655, -81.39412 34.071...       2021-12-18
# 3  POLYGON ((-81.76251 33.19727, -81.74252 33.208...       2021-12-18
# 4  POLYGON ((-81.45630 34.79252, -81.47845 34.821...       2021-12-18
#
#    Sort County x Week     County Count Confirmed Cases Suppressed if 1-4  \
# 0                3562    Pickens                                     212
# 1                2738    Laurens                                      71
# 2                2923  Lexington                                     326
# 3                 535   Barnwell                                      10
# 4                1085    Chester                                      40
#
#   Count Probable Cases Suppressed if 1-4  \
# 0                                     22
# 1                                     48
# 2                                    164
# 3                                      7
# 4                                     32
#
#   Count Hospitalized Cases Suppressed if 1-4  \
# 0                                          7
# 1                                         <5
# 2                                         10
# 3                                         <5
# 4                                         <5
#
#   Count Deceased Cases Suppressed if 1-4
# 0                                      8
# 1                                     <5
# 2                                     <5
# 3                                    NaN
# 4                                    NaN

# %%
# Convert confirmed case columns integers
merge['Count Confirmed Cases Suppressed if 1-4'] = merge['Count Confirmed Cases Suppressed if 1-4'].astype(int)

# %%
# make the map
fig = plt.figure(figsize=(1280/72, 720/72))
ax = fig.add_axes([0, 0, 1, 1], projection=ccrs.PlateCarree(),
                     frameon=False)
ax.patch.set_visible(False)
ax.set_title('South Carolina COVID Cases', fontweight='bold', fontsize='36')

merge.plot(column='Count Confirmed Cases Suppressed if 1-4',
           cmap='OrRd', edgecolor='black',
           scheme='quantiles', legend=True,
           figsize=(1280/72, 720/72),
           ax=ax)

fig.savefig('sc_covid.png', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <module>
#       1 # make the map
# ----> 2 fig = plt.figure(figsize=(1280/72, 720/72))
#       3 ax = fig.add_axes([0, 0, 1, 1], projection=ccrs.PlateCarree(),
#       4                      frameon=False)
#       5 ax.patch.set_visible(False)
#
# NameError: name 'plt' is not defined
